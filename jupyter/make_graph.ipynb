# %% [markdown]
# Use PySpark to load all of the data

# %%
import pyspark

sc = pyspark.SparkContext()

# %%
raw = sc.textFile("../states/*.csv")


splitified = raw.filter(lambda x: x != "state,total_votes,dem_votes,dem_pct,dem_ev,rep_votes,rep_pct,rep_ev,year").map(lambda x: x.replace(",,", ",0,").replace(",*,", ",0,").replace("*", "").replace("--", "0")).map(lambda x: x.split(","))
formatted = splitified.map(lambda x: ((x[0], int(x[8])), (int(x[1]), int(x[2]), float(x[3]), int(x[4]), int(x[5]), float(x[6]), int(x[7]))))

print(splitified.takeSample(False, 5))
print(formatted.takeSample(False, 5))
# Out:
# [['New Mexico', '152225', '81389', '53.5', '4', '70688', '46.4', '0', '1944'], ['Massachusetts', '3473668', '2126518', '61.22', '11', '1251303', '36.02', '0', '2024'], ['Connecticut', '1443394', '676584', '46.9', '0', '750241', '52.0', '8', '1988'], ['Tennessee', '1201182', '357293', '29.7', '0', '813147', '67.7', '10', '1972'], ['New York', '7095971', '2747944', '38.7', '0', '4345506', '61.2', '45', '1956']]
# [(('Wisconsin', 2004), (2997007, 1489504, 49.7, 10, 1478120, 49.3, 0)), (('Connecticut', 1964), (1218578, 826269, 67.8, 8, 390996, 32.1, 0)), (('Florida', 1972), (2583283, 718117, 27.8, 0, 1857759, 71.9, 17)), (('Utah', 1972), (478476, 126284, 26.4, 0, 323643, 67.6, 4)), (('South Dakota', 1972), (307415, 139945, 45.5, 0, 166476, 54.2, 4))]

# %%
sc.stop()
